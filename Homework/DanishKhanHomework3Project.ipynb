# %% [markdown]
# # Danish Ahmed Khan - SYD DAT 7
#
# # Homework 3 - Continuing my Aviation Data Project
# --------------------------------------------------------------------------
#
#
# HW2 REQUIREMENTS
# ****************
#
#
# * For the following use the github repository you made for your project.
# * Load some data you have gathered for your project into Python.
# * Identify some numeric and categorical features in your data. Write this up in a file called README.md
# * Run some summary statistics over the numeric data.
# * Are there any interesting features of the data that jump out?
# * Generate some data visualisations that would be useful for you to explore your data set, particularly the numeric data right now.
# * If you can find any good candidates for a regression, try some regressors out.
#
#
# HW3 REQUIREMENTS - PLEASE SCROLL DOWN, I HAVE MARKED THE POINT WHERE HW3 BEGINS
# ****************
#
# * For the following, continue to use the github repository you made for your project
# * You don't have to use the same data that you used from the previous homework assignment if
#   you have decided to change what your project is about.
# * Identify some attributes where you would expect clustering to be successful.
# * Try two or more different clustering algorithms, and experiment with
#   different numbers of clusters.
# * If the clustering works well, try to give descriptive names for the
#   different clusters you have found. If the clustering isn't
#   successful, try to hypothesise why your data is some homogenous (and
#   try clustering on different attributes).
# * Try building decision trees on your data. If you think simplicity
#   would be good, try to make it as simple as possible. If you think
#   accuracy is more important, use ensembling or any other techniques
#   that you have learned.
# * Evaluate the success of your model (you can use another model from another
#   assigment if this doesn't work well).

# %%
import pandas
import matplotlib
import matplotlib.pyplot
import sklearn.linear_model
import numpy
#importing required libraries

# %% [markdown]
# Information about chosen dataset
# ********************************
#
# The National Transportation Safety Board (NTSB) is an independent U.S. government investigative agency responsible for civil transportation accident investigation.The NTSB aviation accident database contains information from 1962 and later about civil aviation accidents and selected incidents within the United States, its territories and possessions, and in international waters. I am looking to analyze this dataset to investigate patterns and correlations between events. The dataset contains information on location, aircraft type, number of engines etc.

# %%
AviationData = pandas.read_csv('D:/repo1/Homework/AviationDataEnd2016UP.csv')

# %%
AviationData
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20170103X43747            Accident      WPR17LA046  2017-01-03
# 1      20161230X55950            Accident      WPR17FA044  2016-12-29
# 2      20161229X93022            Accident      CEN17LA062  2016-12-27
# 3      20161227X80237            Accident      CEN17LA061  2016-12-27
# 4      20161226X80840            Accident      WPR17FA041  2016-12-26
# 5      20161227X03229            Accident      ERA17FA073  2016-12-26
# 6      20161223X22808            Accident      ERA17FA072  2016-12-23
# 7      20161221X11609            Incident      ENG17WA007  2016-12-21
# 8      20161222X21701            Accident      CEN17LA060  2016-12-21
# 9      20161220X20645            Accident      CEN17LA058  2016-12-18
# 10     20161219X04338            Accident      CEN17LA057  2016-12-16
# 11     20161216X23127            Accident      ANC17FA012  2016-12-15
# ...

# %%
AviationData.columns
# Out:
# Index([u'Event.Id', u'Investigation.Type', u'Accident.Number', u'Event.Date',
#        u'Location', u'Country', u'Latitude', u'Longitude', u'Airport.Code',
#        u'Airport.Name', u'Injury.Severity', u'Aircraft.Damage',
#        u'Aircraft.Category', u'Registration.Number', u'Make', u'Model',
#        u'Amateur.Built', u'Number.of.Engines', u'Engine.Type',
#        u'FAR.Description', u'Schedule', u'Purpose.of.Flight', u'Air.Carrier',
#        u'Total.Fatal.Injuries', u'Total.Serious.Injuries',
#        u'Total.Minor.Injuries', u'Total.Uninjured', u'Weather.Condition',
#        u'Broad.Phase.of.Flight', u'Report.Status', u'Publication.Date'],
#       dtype='object')

# %%
AviationData.describe()
# Out:
# C:\Users\DAKHAN\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#            Latitude     Longitude  Number.of.Engines  Total.Fatal.Injuries  \
# count  25751.000000  25742.000000       75175.000000          55984.000000
# mean      37.690421    -93.781061           1.148055              0.814679
# std       12.148019     39.243662           0.453847              6.233700
# min      -78.016945   -178.676111           0.000000              0.000000
# 25%             NaN           NaN                NaN                   NaN
# 50%             NaN           NaN                NaN                   NaN
# 75%             NaN           NaN                NaN                   NaN
# max       89.218056    177.557778          18.000000            349.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count            53742.000000          54833.000000     66949.000000
# ...

# %%
len(AviationData)
# Out:
# 79293

# %%
AviationData.dtypes
# Out:
# Event.Id                   object
# Investigation.Type         object
# Accident.Number            object
# Event.Date                 object
# Location                   object
# Country                    object
# Latitude                  float64
# Longitude                 float64
# Airport.Code               object
# Airport.Name               object
# Injury.Severity            object
# Aircraft.Damage            object
# Aircraft.Category          object
# Registration.Number        object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# FAR.Description            object
# Schedule                   object
# Purpose.of.Flight          object
# Air.Carrier                object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# ...

# %%
AviationData.shape
# Out:
# (79293, 31)

# %%
AviationData.Latitude.mean()
# Out:
# 37.69042077150383

# %%
AviationData.Longitude.mean()
# Out:
# -93.78106078750662

# %%
AviationData.Latitude.median()
# Out:
# 38.184166

# %%
AviationData.Longitude.median()
# Out:
# -94.49805500000001

# %%
AviationData.head(10)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20170103X43747            Accident      WPR17LA046  2017-01-03
# 1  20161230X55950            Accident      WPR17FA044  2016-12-29
# 2  20161229X93022            Accident      CEN17LA062  2016-12-27
# 3  20161227X80237            Accident      CEN17LA061  2016-12-27
# 4  20161226X80840            Accident      WPR17FA041  2016-12-26
# 5  20161227X03229            Accident      ERA17FA073  2016-12-26
# 6  20161223X22808            Accident      ERA17FA072  2016-12-23
# 7  20161221X11609            Incident      ENG17WA007  2016-12-21
# 8  20161222X21701            Accident      CEN17LA060  2016-12-21
# 9  20161220X20645            Accident      CEN17LA058  2016-12-18
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0     Paradise, MT  United States        NaN         NaN          NaN
# 1        Dabob, WA  United States  47.823611 -122.790000          NaN
# ...

# %%
AviationData.tail(10)
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 79283  20020909X01561            Accident      NYC82DA015  1982-01-01
# 79284  20020909X01560            Accident      MIA82DA029  1982-01-01
# 79285  20020909X01559            Accident      FTW82DA034  1982-01-01
# 79286  20020909X01558            Accident      ATL82DKJ10  1982-01-01
# 79287  20001218X45446            Accident      CHI81LA106  1981-08-01
# 79288  20041105X01764            Accident      CHI79FA064  1979-08-02
# 79289  20001218X45448            Accident      LAX96LA321  1977-06-19
# 79290  20061025X01555            Accident      NYC07LA005  1974-08-30
# 79291  20001218X45447            Accident      LAX94LA336  1962-07-19
# 79292  20001218X45444            Accident      SEA87LA080  1948-10-24
#
#                Location        Country   Latitude  Longitude Airport.Code  \
# 79283  EAST HANOVER, NJ  United States        NaN        NaN          N58
# ...

# %% [markdown]
# # HW 3 START
#
# Please note that this is still somewhat of a work in progress

# %%
# I need to understand the data in more detail

# %%
AviationData.sample(15)
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 74960  20001214X42616            Accident      CHI83FA161  1983-04-08
# 328    20160906X42741            Accident      GAA16CA465  2016-09-05
# 9640   20110222X22256            Accident      WPR11LA140  2011-02-18
# 14881  20080507X00625            Accident      SEA08CA111  2008-04-24
# 12873  20090518X63402            Accident      CEN09CA302  2009-05-16
# 39986  20001208X05350            Accident      ANC96LA048  1996-03-30
# 54304  20001212X22682            Accident      CHI90LA092  1990-03-02
# 39527  20001208X05924            Accident      CHI96LA197  1996-06-08
# 10880  20100624X50724            Accident      ERA10LA330  2010-06-18
# 43770  20001206X01731            Accident      FTW94FA231  1994-07-13
# 79172  20020917X01997            Accident      FTW82DA042  1982-01-19
# 55690  20001213X28882            Accident      LAX89LA257  1989-07-27
# ...

# %%
AviationData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79293 entries, 0 to 79292
# Data columns (total 31 columns):
# Event.Id                  79293 non-null object
# Investigation.Type        79293 non-null object
# Accident.Number           79293 non-null object
# Event.Date                79293 non-null object
# Location                  79215 non-null object
# Country                   78786 non-null object
# Latitude                  25751 non-null float64
# Longitude                 25742 non-null float64
# Airport.Code              44666 non-null object
# Airport.Name              47439 non-null object
# Injury.Severity           79293 non-null object
# Aircraft.Damage           76883 non-null object
# Aircraft.Category         22477 non-null object
# Registration.Number       76209 non-null object
# Make                      79204 non-null object
# Model                     79175 non-null object
# Amateur.Built             78721 non-null object
# ...

# %%
# I need to maniupulate the date field

# %%
AviationData['Event.Date']
# Out:
# 0        2017-01-03
# 1        2016-12-29
# 2        2016-12-27
# 3        2016-12-27
# 4        2016-12-26
# 5        2016-12-26
# 6        2016-12-23
# 7        2016-12-21
# 8        2016-12-21
# 9        2016-12-18
# 10       2016-12-16
# 11       2016-12-15
# 12       2016-12-12
# 13       2016-12-12
# 14       2016-12-11
# 15       2016-12-11
# 16       2016-12-11
# 17       2016-12-10
# 18       2016-12-10
# 19       2016-12-10
# 20       2016-12-09
# 21       2016-12-08
# 22       2016-12-07
# 23       2016-12-07
# 24       2016-12-07
# 25       2016-12-07
# 26       2016-12-06
# 27       2016-12-05
# 28       2016-12-05
# 29       2016-12-04
#             ...
# 79263    1982-01-03
# 79264    1982-01-03
# 79265    1982-01-03
# 79266    1982-01-03
# 79267    1982-01-03
# 79268    1982-01-03
# 79269    1982-01-03
# 79270    1982-01-03
# 79271    1982-01-02
# 79272    1982-01-02
# 79273    1982-01-02
# 79274    1982-01-02
# 79275    1982-01-02
# 79276    1982-01-02
# ...

# %%
AviationData['New_Date'] = AviationData['Event.Date'].astype('datetime64[ns]', errors='coerce')

# %%
AviationData.head(10)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20170103X43747            Accident      WPR17LA046  2017-01-03
# 1  20161230X55950            Accident      WPR17FA044  2016-12-29
# 2  20161229X93022            Accident      CEN17LA062  2016-12-27
# 3  20161227X80237            Accident      CEN17LA061  2016-12-27
# 4  20161226X80840            Accident      WPR17FA041  2016-12-26
# 5  20161227X03229            Accident      ERA17FA073  2016-12-26
# 6  20161223X22808            Accident      ERA17FA072  2016-12-23
# 7  20161221X11609            Incident      ENG17WA007  2016-12-21
# 8  20161222X21701            Accident      CEN17LA060  2016-12-21
# 9  20161220X20645            Accident      CEN17LA058  2016-12-18
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0     Paradise, MT  United States        NaN         NaN          NaN
# 1        Dabob, WA  United States  47.823611 -122.790000          NaN
# ...

# %%
AviationData['Month'] = AviationData['New_Date'].map(lambda x: x.month)

# %%
AviationData.tail(10)
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 79283  20020909X01561            Accident      NYC82DA015  1982-01-01
# 79284  20020909X01560            Accident      MIA82DA029  1982-01-01
# 79285  20020909X01559            Accident      FTW82DA034  1982-01-01
# 79286  20020909X01558            Accident      ATL82DKJ10  1982-01-01
# 79287  20001218X45446            Accident      CHI81LA106  1981-08-01
# 79288  20041105X01764            Accident      CHI79FA064  1979-08-02
# 79289  20001218X45448            Accident      LAX96LA321  1977-06-19
# 79290  20061025X01555            Accident      NYC07LA005  1974-08-30
# 79291  20001218X45447            Accident      LAX94LA336  1962-07-19
# 79292  20001218X45444            Accident      SEA87LA080  1948-10-24
#
#                Location        Country   Latitude  Longitude Airport.Code  \
# 79283  EAST HANOVER, NJ  United States        NaN        NaN          N58
# ...

# %%
AviationData.dtypes
# Out:
# Event.Id                          object
# Investigation.Type                object
# Accident.Number                   object
# Event.Date                        object
# Location                          object
# Country                           object
# Latitude                         float64
# Longitude                        float64
# Airport.Code                      object
# Airport.Name                      object
# Injury.Severity                   object
# Aircraft.Damage                   object
# Aircraft.Category                 object
# Registration.Number               object
# Make                              object
# Model                             object
# Amateur.Built                     object
# Number.of.Engines                float64
# Engine.Type                       object
# FAR.Description                   object
# Schedule                          object
# Purpose.of.Flight                 object
# Air.Carrier                       object
# ...

# %%
AviationData['Month'].value_counts()
# Out:
# 7     9504
# 8     8983
# 6     8544
# 5     7626
# 9     7382
# 4     6549
# 10    6165
# 3     5994
# 11    4907
# 2     4680
# 12    4511
# 1     4448
# Name: Month, dtype: int64

# %%
AviationData['Month'].value_counts().plot()

# %%
# %matplotlib inline

# %%
AviationData['Month'].value_counts().plot()

# %%
AviationData['Month'].value_counts().sort
# Out:
# <bound method Series.sort of 7     9504
# 8     8983
# 6     8544
# 5     7626
# 9     7382
# 4     6549
# 10    6165
# 3     5994
# 11    4907
# 2     4680
# 12    4511
# 1     4448
# Name: Month, dtype: int64>

# %%
AviationData['Month'].value_counts().plot.bar()

# %%
# Above plot shows number of accidents by month

# How do I sort the month on the x axis?

# %%
AviationData.sort_values(by=['Month'], ascending=True)
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20170103X43747            Accident      WPR17LA046  2017-01-03
# 11584  20100119X00231            Accident      ANC10LA013  2010-01-19
# 11583  20100121X11234            Accident      CEN10LA105  2010-01-19
# 11582  20100121X82958            Incident      DCA10IA022  2010-01-19
# 11581  20100129X00036            Incident      DCA10WA026  2010-01-19
# 11580  20100120X52727            Accident      ERA10LA121  2010-01-19
# 11579  20100203X01641            Accident      CEN10WA112  2010-01-20
# 11578  20100125X41838            Accident      ANC10FA014  2010-01-21
# 11577  20100122X04141            Accident      CEN10CA106  2010-01-21
# 11576  20100129X92638            Accident      DCA10WA025  2010-01-21
# 11575  20100507X93350            Incident      ENG10WA028  2010-01-21
# 11574  20100124X35117            Accident      ERA10CA122  2010-01-21
# ...

# %%
import seaborn

# %%
AviationData.plot.scatter("Longitude", "Latitude")

# %%
# Above plot shows # accidents by Latitude & Longtitude - I can clearly see sone clusters of data points

# %%
AviationData.plot.scatter("Longitude", "Latitude", c=AviationData.Month, colormap = matplotlib.pyplot.cm.rainbow)

# %%
AviationData.dtypes
# Out:
# Event.Id                          object
# Investigation.Type                object
# Accident.Number                   object
# Event.Date                        object
# Location                          object
# Country                           object
# Latitude                         float64
# Longitude                        float64
# Airport.Code                      object
# Airport.Name                      object
# Injury.Severity                   object
# Aircraft.Damage                   object
# Aircraft.Category                 object
# Registration.Number               object
# Make                              object
# Model                             object
# Amateur.Built                     object
# Number.of.Engines                float64
# Engine.Type                       object
# FAR.Description                   object
# Schedule                          object
# Purpose.of.Flight                 object
# Air.Carrier                       object
# ...

# %%
AviationData.rename(columns = {'Broad.Phase.of.Flight' : 'FlightPhase'}, inplace=True)

# %%
AviationData.head(2)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20170103X43747            Accident      WPR17LA046  2017-01-03
# 1  20161230X55950            Accident      WPR17FA044  2016-12-29
#
#        Location        Country   Latitude  Longitude Airport.Code  \
# 0  Paradise, MT  United States        NaN        NaN          NaN
# 1     Dabob, WA  United States  47.823611    -122.79          NaN
#
#   Airport.Name  ...  Total.Fatal.Injuries Total.Serious.Injuries  \
# 0          NaN  ...                   NaN                    2.0
# 1          NaN  ...                   4.0                    NaN
#
#   Total.Minor.Injuries Total.Uninjured Weather.Condition FlightPhase  \
# 0                  NaN             NaN               VMC      CRUISE
# 1                  NaN             NaN               VMC         NaN
#
#   Report.Status  Publication.Date   New_Date Month
# 0   Preliminary        05/01/2017 2017-01-03     1
# ...

# %%
AviationData.FlightPhase.unique()
# Out:
# array(['CRUISE', nan, 'LANDING', 'TAKEOFF', 'DESCENT', 'APPROACH', 'OTHER',
#        'TAXI', 'GO-AROUND', 'MANEUVERING', 'UNKNOWN', 'STANDING', 'CLIMB'], dtype=object)

# %%
AviationData[AviationData.FlightPhase == 'nan']
# Out:
# Empty DataFrame
# Columns: [Event.Id, Investigation.Type, Accident.Number, Event.Date, Location, Country, Latitude, Longitude, Airport.Code, Airport.Name, Injury.Severity, Aircraft.Damage, Aircraft.Category, Registration.Number, Make, Model, Amateur.Built, Number.of.Engines, Engine.Type, FAR.Description, Schedule, Purpose.of.Flight, Air.Carrier, Total.Fatal.Injuries, Total.Serious.Injuries, Total.Minor.Injuries, Total.Uninjured, Weather.Condition, FlightPhase, Report.Status, Publication.Date, New_Date, Month]
# Index: []
#
# [0 rows x 33 columns]

# %%
AviationData[AviationData.FlightPhase == 'OTHER']
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 18     20161212X22111            Accident      CEN17WA054  2016-12-10
# 166    20161011X64047            Accident      ERA17FA011  2016-10-11
# 379    20160829X14027            Accident      GAA16CA451  2016-08-25
# 1178   20160323X62352            Accident      GAA16CA156  2016-03-21
# 1511   20151201X72017            Accident      ERA16LA054  2015-11-26
# 1557   20151119X05932            Accident      CEN16WA045  2015-11-14
# 1726   20151005X10531            Accident      CEN16WA002  2015-10-03
# 1939   20150902X14701            Accident      CEN15WA397  2015-08-22
# 2082   20150924X33526            Accident      CEN15WA420  2015-07-31
# 2771   20150323X05503            Accident      CEN15WA176  2015-03-12
# 3018   20141219X60358            Accident      CEN15WA082  2014-12-18
# 3143   20141031X74653            Accident      DCA15MA019  2014-10-31
# ...

# %%
AviationData.FlightPhase.value_counts()
# Out:
# LANDING        19209
# TAKEOFF        15284
# CRUISE         10749
# MANEUVERING     9818
# APPROACH        7720
# TAXI            2322
# CLIMB           2279
# DESCENT         2202
# GO-AROUND       1608
# STANDING        1219
# UNKNOWN          672
# OTHER            157
# Name: FlightPhase, dtype: int64

# %%
#Visualizing number of accidents by flight phase

# %%
AviationData['FlightPhase'].value_counts().plot(kind='bar', title='Phase of Flight')

# %%
AviationData['FlightPhase'].value_counts().plot(kind='pie', title='Phase of Flight')

# %%
AviationData['FlightPhase'].value_counts()
# Out:
# LANDING        19209
# TAKEOFF        15284
# CRUISE         10749
# MANEUVERING     9818
# APPROACH        7720
# TAXI            2322
# CLIMB           2279
# DESCENT         2202
# GO-AROUND       1608
# STANDING        1219
# UNKNOWN          672
# OTHER            157
# Name: FlightPhase, dtype: int64

# %%
import math

# %%
from sklearn.cluster import KMeans

# %%
import sklearn.cluster
Clusterer = KMeans(n_clusters=10)
Location = AviationData[['Latitude','Longitude']]

# %%
AvData2 = AviationData.dropna(axis=0, subset=['Latitude', 'Longitude'])

# %%
AvData2
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 1      20161230X55950            Accident      WPR17FA044  2016-12-29
# 3      20161227X80237            Accident      CEN17LA061  2016-12-27
# 4      20161226X80840            Accident      WPR17FA041  2016-12-26
# 5      20161227X03229            Accident      ERA17FA073  2016-12-26
# 6      20161223X22808            Accident      ERA17FA072  2016-12-23
# 8      20161222X21701            Accident      CEN17LA060  2016-12-21
# 9      20161220X20645            Accident      CEN17LA058  2016-12-18
# 10     20161219X04338            Accident      CEN17LA057  2016-12-16
# 11     20161216X23127            Accident      ANC17FA012  2016-12-15
# 12     20161212X23428            Accident      WPR17FA035  2016-12-12
# 14     20161213X85858            Accident      WPR17LA037  2016-12-11
# 15     20161212X85310            Accident      WPR17LA036  2016-12-11
# ...

# %%
AviationData
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20170103X43747            Accident      WPR17LA046  2017-01-03
# 1      20161230X55950            Accident      WPR17FA044  2016-12-29
# 2      20161229X93022            Accident      CEN17LA062  2016-12-27
# 3      20161227X80237            Accident      CEN17LA061  2016-12-27
# 4      20161226X80840            Accident      WPR17FA041  2016-12-26
# 5      20161227X03229            Accident      ERA17FA073  2016-12-26
# 6      20161223X22808            Accident      ERA17FA072  2016-12-23
# 7      20161221X11609            Incident      ENG17WA007  2016-12-21
# 8      20161222X21701            Accident      CEN17LA060  2016-12-21
# 9      20161220X20645            Accident      CEN17LA058  2016-12-18
# 10     20161219X04338            Accident      CEN17LA057  2016-12-16
# 11     20161216X23127            Accident      ANC17FA012  2016-12-15
# ...

# %%
Clusterer = KMeans(n_clusters=10)
Location = AvData2[['Longitude','Latitude']]
Kmodel = Clusterer.fit(Location)

# %%
Location
# Out:
#         Longitude   Latitude
# 1     -122.790000  47.823611
# 3      -90.428611  37.761111
# 4     -119.870834  36.844444
# 5      -83.458333  35.651944
# 6      -73.094444  43.981389
# 8       81.955833  40.536666
# 9      -93.162778  45.195555
# 10     -85.060556  42.938055
# 11    -159.620834  60.944444
# 12    -109.752778  38.753056
# 14    -122.662500  48.498611
# 15    -115.970000  34.066667
# 16     -72.908611  40.956944
# 17     -76.918056  36.646389
# 19     -97.760556  28.171389
# 20     -88.627500  42.225556
# 22       7.070834  47.594444
# 23    -108.336389  44.321945
# 24    -154.117223  60.297222
# 25    -147.773889  64.548611
# 26    -119.850556  34.433334
# 27    -113.996944  46.875834
# 28     -84.154722  31.219723
# 29    -121.400556  38.667778
# 30    -122.633889  38.232500
# 31     -98.468334  29.531389
# 35    -106.931667  38.534444
# 36     -85.863333  41.531389
# 37     167.772500  37.933334
# 38    -166.708056  53.785833
# ...           ...        ...
# ...

# %%
centroids = Kmodel.cluster_centers_

# %%
centroids
# Out:
# array([[ -82.87942858,   30.10233274],
#        [ 143.37047931,  -21.34972768],
#        [-116.86847019,   39.43401246],
#        [   9.26861404,   39.68724923],
#        [ -79.23503174,   40.77067593],
#        [-157.1890536 ,   18.96979167],
#        [ -97.30186187,   36.72409687],
#        [ -62.60235984,   -9.15986049],
#        [-151.01460349,   61.60514172],
#        [  98.86313506,   36.11171484]])

# %%
len(centroids)
# Out:
# 10

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.scatter(Clusterer.cluster_centers_[:,0],
                          Clusterer.cluster_centers_[:,1],
                          s=100)

# %%
matplotlib.pyplot.scatter(AvData2.Latitude, AvData2.Longitude)

# %%
matplotlib.pyplot.scatter(AviationData.Latitude, AviationData.Longitude)

# %%
AvData2.plot.scatter("Longitude", "Latitude")

# %%
centroids
Lon, Lat = zip(*centroids)
print(Lon)
print(Lat)
# Out:
# (-82.879428578716173, 143.37047931372547, -116.86847019208318, 9.2686140400843584, -79.23503173677463, -157.18905360465112, -97.301861870540264, -62.602359843181809, -151.01460348571436, 98.86313505780349)
# (30.102332743714939, -21.349727679738606, 39.434012464331481, 39.687249227848099, 40.770675926047957, 18.969791674418598, 36.72409687359837, -9.1598604886363475, 61.60514171785718, 36.111714843930635)

# %%
matplotlib.pyplot.scatter(Lon, Lat, s=100)

# %%
import sklearn.metrics

# %%
Clusterer_suggestions = Clusterer.fit_predict(Location)

# %%
Clusterer_suggestions
# Out:
# array([5, 0, 5, ..., 5, 2, 8])

# %%
sklearn.metrics.silhouette_score(Location, Clusterer_suggestions)
# Out:
# 0.45934541221204622

# %%
#Question: How do i superimpose cluster on actual Longitude, Latitude Data?

# %% [markdown]
# Trying DBSCAN NOW

# %%
ClustererDB = sklearn.cluster.DBSCAN(eps=100,min_samples=10)
LocationDB = AvData2[['Longitude','Latitude']]
DBModel = ClustererDB.fit(LocationDB)

# %%
DBscan_suggestions = DBModel.fit_predict(LocationDB)

# %%
DBscan_suggestions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
